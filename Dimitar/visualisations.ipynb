# %%
import pandas as pd
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']

results = [["Template Adam", 0.33, 0.34, 0.33, 0.32],
           ['Template SGD', 0.32, 0.33, 0.32, 0.31],
           ['ResNet18 Adam', 0.38, 0.39, 0.38, 0.33],
           ['ResNet18 SGD', 0.39, 0.39, 0.39, 0.39],
           ['Densenet121 Adam', 0.41, 0.43, 0.41, 0.40],
           ['Densenet121 SGD', 0.39, 0.39, 0.39, 0.39]]

class_Densenet_Adam = [[labels[0],       0.47   ,   0.28   ,   0.35],
           [labels[1],       0.55   ,   0.57   ,   0.56],
           [labels[2] ,      0.38  ,    0.16   ,   0.23],
           [labels[3],       0.28  ,    0.53  ,    0.37],
           [labels[4],       0.44  ,    0.30  ,    0.36],
           [labels[5] ,      0.48  ,    0.64  ,    0.54]]

class_Densenet_SGD = [          [labels[0],       0.37   ,   0.44   ,   0.40 ],      
         [  labels[1]   ,    0.49  ,    0.57   ,   0.53 ],      
          [ labels[2]   ,    0.32  ,    0.27  ,    0.29 ],      
          [ labels[3]   ,    0.30  ,    0.26   ,   0.28] ,      
          [ labels[4]    ,   0.32   ,   0.37   ,   0.34 ],      
          [ labels[5]   ,    0.55   ,   0.43   ,   0.48]]

class_Template_Adam = [[labels[0]    ,   0.40   ,  0.26    ,  0.31],
           [labels[1]   ,    0.38  ,    0.52   ,   0.44],
           [labels[2]    ,   0.24  ,    0.30  ,    0.27],
           [labels[3]   ,    0.27   ,   0.28   ,   0.27],
           [labels[4]   ,    0.32   ,   0.13  ,    0.19],
           [labels[5]    ,   0.42   ,   0.51   ,   0.46]]

class_Template_SGD = [ [labels[0] ,      0.31   ,   0.52   ,   0.39 ],      
           [labels[1]   ,    0.36  ,    0.53   ,   0.42 ]  ,    
           [labels[2]   ,    0.25  ,    0.22  ,    0.24 ]  ,    
           [labels[3]    ,   0.26   ,   0.28  ,    0.27  ] ,    
           [labels[4]   ,    0.33   ,   0.13  ,    0.18 ] ,     
           [labels[5]    ,   0.50    ,  0.26  ,    0.34]]

class_ResNet_Adam = [[labels[0]   ,    0.42  ,    0.26  ,    0.33],       
           [labels[1]   ,    0.43  ,    0.69  ,    0.53],       
           [labels[2]   ,    0.40  ,    0.07  ,    0.13 ],      
           [labels[3]    ,   0.28  ,    0.51  ,    0.36 ] ,     
           [labels[4]   ,    0.42 ,     0.08  ,    0.13 ],      
           [labels[5]   ,    0.41  ,    0.66   ,   0.51]]

class_ResNet_SGD = [[labels[0]    ,   0.42   ,   0.42   ,   0.42],       
           [labels[1]    ,   0.49  ,    0.55  ,    0.52],      
           [labels[2]    ,   0.31  ,    0.29  ,    0.30],      
           [labels[3]    ,   0.28  ,    0.23  ,    0.26],     
           [labels[4]   ,    0.35   ,   0.34  ,    0.35 ],      
           [labels[5]    ,   0.47   ,   0.54  ,    0.50]]

Experiment_df = pd.DataFrame(results, columns=['Model', 'Accuracy', 'Weighted precision', 'Weighted recall', 'Weighted F1-score'])
class1_df = pd.DataFrame(class_Densenet_Adam, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class2_df = pd.DataFrame(class_Densenet_SGD, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class3_df = pd.DataFrame(class_Template_Adam, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class4_df = pd.DataFrame(class_Template_SGD, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class5_df = pd.DataFrame(class_ResNet_Adam, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class6_df = pd.DataFrame(class_ResNet_SGD, columns=['Class', 'Precision', 'Recall', 'F1-score'])

# %%
class1_df
# Out:
#           Class  Precision  Recall  F1-score
# 0   Atelectasis       0.47    0.28      0.35
# 1      Effusion       0.55    0.57      0.56
# 2  Infiltration       0.38    0.16      0.23
# 3    No Finding       0.28    0.53      0.37
# 4        Nodule       0.44    0.30      0.36
# 5  Pneumothorax       0.48    0.64      0.54

# %%
class4_df
# Out:
#           Class  Precision  Recall  F1-score
# 0   Atelectasis       0.31    0.52      0.39
# 1      Effusion       0.36    0.53      0.42
# 2  Infiltration       0.25    0.22      0.24
# 3    No Finding       0.26    0.28      0.27
# 4        Nodule       0.33    0.13      0.18
# 5  Pneumothorax       0.50    0.26      0.34

# %%
Experiment_df
# Out:
#               Model  Accuracy  Weighted precision  Weighted recall  \
# 0     Template Adam      0.33                0.34             0.33
# 1      Template SGD      0.32                0.33             0.32
# 2     ResNet18 Adam      0.38                0.39             0.38
# 3      ResNet18 SGD      0.39                0.39             0.39
# 4  Densenet121 Adam      0.41                0.43             0.41
# 5   Densenet121 SGD      0.39                0.39             0.39
#
#    Weighted F1-score
# 0               0.32
# 1               0.31
# 2               0.33
# 3               0.39
# 4               0.40
# 5               0.39

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# create a matrix
matrix_Densenet_Adam = np.array([[188, 88, 28, 201, 62, 114],
 [ 47, 388, 31, 62, 25, 128],
 [ 43, 99, 111, 283, 55, 90],
 [ 62, 49, 52, 363, 79, 76],
 [ 42, 29, 49, 284, 207, 70],
 [ 18, 55, 25, 103, 46, 434]]
)

matrix_Densenet_SGD = np.array([[298,  97,  62,  67, 112,  45],
 [ 93, 388,  44,  45,  70, 41],
 [110,  88, 181, 121, 124,  57],
 [116,  79, 128, 177, 139,  42],
 [108,  49,  93, 118, 255,  58],
 [89, 90,  55,  56,  99, 292]]
)

matrix_Template_Adam = np.array([[177, 143, 132, 124,  40,  65],
 [ 59, 357,  98,  30,  30, 107],
 [ 53, 151, 205, 143,  29, 100],
 [ 71,  99, 166, 193,  64,  88],
 [ 50,  82, 152, 185,  89, 123],
 [ 38, 110, 113,  52,  24, 344]]

)

matrix_Template_SGD = np.array([[354, 130,  62,  89,  27,  19],
 [171, 360,  57,  33,  23,  37],
 [159, 176, 150, 137,  31,  28],
 [176, 104, 110, 188,  63,  40],
 [164,  88, 107, 184,  86,  52],
 [130, 156, 109,  80,  30, 176]]

)

matrix_ResNet_Adam = np.array([[180, 188,  18, 166,  12, 117],
 [ 30, 471,  14,  50,   8, 108],
 [ 79, 140,  51, 261,  22, 128],
 [ 64, 105,  27, 344,  23, 118],
 [ 52,  79,  11, 320,  53, 166],
 [ 20, 115,   6,  81,   9, 450]]

)

matrix_Resnet_SGD = np.array([[284,  93,  69,  78,  80,  77],
 [ 77, 375,  63,  34,  39,  93],
 [101,  95, 195, 118, 100,  72],
 [ 95,  80, 137, 160, 133,  76],
 [ 76,  49, 108, 127, 231,  90],
 [ 47,  78,  61,  55,  73, 367]]

)

# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Densenet_Adam / np.sum(matrix_Densenet_Adam, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Densenet Adam (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Densenet_SGD / np.sum(matrix_Densenet_SGD, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Densenet SGD (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Template_Adam / np.sum(matrix_Template_Adam, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Template Adam (%)\n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Template_SGD / np.sum(matrix_Template_SGD, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Template SGD (%)\n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_ResNet_Adam / np.sum(matrix_ResNet_Adam, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Resnet Adam (%)\n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Resnet_SGD / np.sum(matrix_Resnet_SGD, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Resnet SGD (%)\n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
# Experiment 2 
import pandas as pd
labels2 = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']

results2 = [["Template Adam", 0.29, 0.28, 0.29, 0.28],
           ['Template SGD', 0.29, 0.28, 0.29, 0.27],
           ['ResNet18 Adam', 0.36, 0.36, 0.36, 0.34],
           ['ResNet18 SGD', 0.35, 0.35, 0.35, 0.34],
           ['Densenet121 Adam', 0.38, 0.37, 0.38, 0.37],
           ['Densenet121 SGD', 0.36, 0.36, 0.36, 0.35]]

class_Densenet_Adam2 = [[labels2[0]   ,    0.35  ,    0.47   ,   0.40],      
           [labels2[1]   ,    0.49   ,   0.56   ,   0.52],      
           [labels2[2]   ,    0.29   ,   0.19   ,   0.23],      
           [labels2[3]    ,   0.32   ,   0.14  ,    0.20],      
           [labels2[4]   ,    0.31   ,   0.45   ,   0.37],      
           [labels2[5]   ,    0.48   ,   0.46  ,    0.47]]

class_Densenet_SGD2 = [          [labels2[0]   ,    0.37 ,     0.37    ,  0.37],      
           [labels2[1]    ,   0.49  ,    0.45    ,  0.47],      
           [labels2[2]    ,   0.27   ,   0.33  ,    0.30],      
           [labels2[3]    ,   0.26   ,   0.16  ,    0.20],      
           [labels2[4]    ,   0.30   ,   0.33   ,   0.31],      
           [labels2[5]    ,   0.45  ,    0.51   ,   0.48]]

class_Template_Adam2 = [ [labels2[0]   ,    0.30   ,   0.35  ,    0.33],      
           [labels2[1]   ,    0.35   ,   0.37  ,    0.36],     
           [labels2[2]    ,   0.23    ,  0.12   ,   0.16] ,     
           [labels2[3]    ,   0.25   ,   0.15   ,   0.19] ,     
           [labels2[4]    ,   0.27  ,    0.31  ,    0.29] ,     
           [labels2[5]    ,   0.30   ,   0.46   ,   0.37]]

class_Template_SGD2 = [  [labels2[0]   ,    0.28  ,    0.43   ,   0.34],      
           [labels2[1]     ,  0.34  ,    0.41   ,   0.37]    ,  
           [labels2[2]    ,   0.20  ,    0.10  ,    0.13] ,     
           [labels2[3]    ,   0.25   ,   0.08  ,    0.12] ,     
           [labels2[4]   ,    0.27  ,    0.36  ,    0.31] ,     
           [labels2[5]    ,   0.31   ,   0.36  ,    0.34] ]

class_ResNet_Adam2 = [ [0    ,   0.32  ,    0.49   ,   0.38]   ,   
           [labels2[1]    ,   0.45   ,   0.51   ,   0.48]   ,  
           [labels2[2]   ,    0.33   ,   0.11   ,   0.17]   ,   
           [labels2[3]   ,    0.29   ,   0.38  ,    0.33]  ,    
           [labels2[4]    ,   0.34  ,    0.18  ,    0.23] ,     
           [labels2[5]   ,    0.44   ,   0.51   ,   0.47]]

class_ResNet_SGD2 = [[labels2[0]   ,    0.34    ,  0.33  ,    0.34] ,     
           [labels2[1]   ,    0.45   ,   0.44  ,    0.44]   ,   
           [labels2[2]    ,   0.30   ,   0.25   ,   0.27]   ,   
           [labels2[3]     ,  0.26   ,   0.37   ,   0.31]  ,    
           [labels2[4]     ,  0.30  ,    0.21   ,   0.25]  ,   
           [labels2[5]     ,  0.44   ,   0.49   ,   0.46]]

Experiment_df2 = pd.DataFrame(results2, columns=['Model', 'Accuracy', 'Weighted precision', 'Weighted recall', 'Weighted F1-score'])
class1_df2 = pd.DataFrame(class_Densenet_Adam2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class2_df2 = pd.DataFrame(class_Densenet_SGD2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class3_df2 = pd.DataFrame(class_Template_Adam2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class4_df2 = pd.DataFrame(class_Template_SGD2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class5_df2 = pd.DataFrame(class_ResNet_Adam2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
class6_df2 = pd.DataFrame(class_ResNet_SGD2, columns=['Class', 'Precision', 'Recall', 'F1-score'])
Experiment_df2
# Out:
#               Model  Accuracy  Weighted precision  Weighted recall  \
# 0     Template Adam      0.29                0.28             0.29
# 1      Template SGD      0.29                0.28             0.29
# 2     ResNet18 Adam      0.36                0.36             0.36
# 3      ResNet18 SGD      0.35                0.35             0.35
# 4  Densenet121 Adam      0.38                0.37             0.38
# 5   Densenet121 SGD      0.36                0.36             0.36
#
#    Weighted F1-score
# 0               0.28
# 1               0.27
# 2               0.34
# 3               0.34
# 4               0.37
# 5               0.35

# %%
class1_df2
# Out:
#           Class  Precision  Recall  F1-score
# 0   Atelectasis       0.35    0.47      0.40
# 1      Effusion       0.49    0.56      0.52
# 2  Infiltration       0.29    0.19      0.23
# 3    No Finding       0.32    0.14      0.20
# 4        Nodule       0.31    0.45      0.37
# 5  Pneumothorax       0.48    0.46      0.47

# %%
class4_df2
# Out:
#           Class  Precision  Recall  F1-score
# 0   Atelectasis       0.28    0.43      0.34
# 1      Effusion       0.34    0.41      0.37
# 2  Infiltration       0.20    0.10      0.13
# 3    No Finding       0.25    0.08      0.12
# 4        Nodule       0.27    0.36      0.31
# 5  Pneumothorax       0.31    0.36      0.34

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# create a matrix
matrix_Densenet_Adam2 = np.array([[641 ,220 , 97,  44 ,248, 112],
 [184, 763, 125  ,32 ,116, 142],
 [289 ,192 ,259, 148 ,348, 126],
 [292, 117, 169, 196 ,463, 125],
 [270 , 76 ,118, 117, 619, 162],
 [160, 190 ,127 , 74 ,185, 626]]

)

matrix_Densenet_SGD2 = np.array([[504 ,158 ,263 ,132, 164 ,141],
 [161, 615, 169,  94 ,111, 212],
 [209, 145, 450, 164 ,257, 137],
 [190, 112 ,317, 220, 352, 171],
 [186,  82, 302, 166 ,445 ,181],
 [121, 137, 171,  85, 151, 697]]

)

matrix_Template_Adam2 = np.array([[482, 253 , 91, 123, 216, 197],
 [244, 506,  94 , 58 ,115 ,345],
 [265, 248, 161, 157, 249 ,282],
 [223, 131, 116, 205 ,388, 299],
 [215, 119 ,118 ,186 ,417, 307],
 [160, 200, 108 , 97, 170 ,627]]


)

matrix_Template_SGD2 = np.array([[583 ,243,  90 , 77, 223, 146],
 [325 ,557 , 80,  26 ,132, 242],
 [315, 300 ,135,  72, 297 ,243],
 [323, 149 ,121 ,110, 436, 223],
 [286, 123, 130 , 98 ,486 ,239],
 [236 ,249, 120 , 50 ,210 ,497]]


)

matrix_ResNet_Adam2 = np.array([[661, 218,  42, 221,  77, 143],
 [270, 698 , 65 , 74 , 35, 220],
 [336, 202, 151 ,392, 113 ,168],
 [308, 126,  67 ,524, 172 ,165],
 [292, 136,  73 ,436, 241, 184],
 [231, 168,  59, 145,  70, 689]]


)

matrix_Resnet_SGD2 = np.array([[455 ,190, 145, 280, 136 ,156],
 [212, 595 ,136 ,156 , 78, 185],
 [196, 158, 335, 341, 169, 163],
 [190, 108, 207, 502, 184, 171],
 [167 , 96 ,184 ,443, 283, 189],
 [129, 179, 117, 181 , 90, 666]]


)

# sns.heatmap(matrix_Densenet_Adam, cmap="YlGnBu")
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Densenet_Adam2 / np.sum(matrix_Densenet_Adam2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Densenet121 Adam (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Densenet_SGD2 / np.sum(matrix_Densenet_SGD2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Densenet SGD (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Template_Adam2 / np.sum(matrix_Template_Adam2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Template Adam (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Template_SGD2 / np.sum(matrix_Template_SGD2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for Template SGD (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_ResNet_Adam2 / np.sum(matrix_ResNet_Adam2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for ResNet Adam (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()

# %%
labels = ['Atelectasis', 'Effusion', 'Infiltration', 'No Finding', 'Nodule', 'Pneumothorax']
fig, fx = plt.subplots(nrows=1, ncols=1, figsize=(9,7))
sns.heatmap(matrix_Resnet_SGD2 / np.sum(matrix_Resnet_SGD2, axis=1) * 100, annot=True, fmt=".2f",cmap="GnBu", ax=fx)
fx.set_title('Normalized Confusion Matrix for ResNet SGD (%) \n')
fx.set_xlabel('\n Predicted Values\n')
fx.set_ylabel('Actual Values\n')
fx.xaxis.set_ticklabels(labels)
fx.yaxis.set_ticklabels(labels)
plt.show()
